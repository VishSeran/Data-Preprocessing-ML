# %% [markdown]
# ## Hands-on lab: Exploratory Data Analysis - Laptops Pricing dataset

# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
#  - Visualize individual feature patterns
#  - Run descriptive statistical analysis on the dataset
#  - Use groups and pivot tables to find the effect of categorical variables on price
#  - Use Pearson Correlation to measure the interdependence between variables

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %%
def download (url, fileName):
    response = requests.get(url)
    if(response.status_code == 200):
        with open (fileName, "wb")  as f:
            f.write(response.content)

# %%
filepath="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv"

# %%
download (filepath, "LaptopPrice.csv")
file_name = "LaptopPrice.csv"

# %%
df = pd.read_csv(file_name)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0             0           0         Acer         4    2   1         5
# 1             1           1         Dell         3    1   1         3
# 2             2           2         Dell         3    1   1         7
# 3             3           3         Dell         4    2   1         5
# 4             4           4           HP         4    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256        3.52800
# 1              15.6       0.689655       4             256        4.85100
# 2              15.6       0.931034       8             256        4.85100
# 3              13.3       0.551724       8             128        2.69010
# 4              15.6       0.620690       8             256        4.21155
#
#    Price Price-binned  Screen-Full_HD  Screen-IPS_panel
# 0    978          Low               0                 1
# 1    634          Low               1                 0
# 2    946          Low               1                 0
# 3   1244          Low               0                 1
# 4    837          Low               1                 0

# %% [markdown]
# # Task 1 - Visualize individual feature patterns
#
# ### Continuous valued features
# Generate regression plots for each of the parameters "CPU_frequency", "Screen_Size_inch" and "Weight_pounds" against "Price". Also, print the value of correlation of each feature with "Price".

# %%
# CPU_frequency plot

sns.regplot(x = 'CPU_frequency', y= 'Price', data= df)
plt.ylim(0,)
# Out:
# (0.0, 3974.15)

# %%
sns.regplot(x = 'Screen_Size_inch', y ='Price', data =df)
plt.ylim(0,)
sns.regplot(x = 'Weight_pounds', y= 'Price', data =df)
plt.ylim(0,)
# Out:
# (0.0, 3974.15)

# %%
for column in ['CPU_frequency','Screen_Size_inch','Weight_pounds']:
    print("Correlation between Price and the {colum}: " , df[[column, 'Price']].corr())
# Out:
# Correlation between Price and the {colum}:                 CPU_frequency     Price
# CPU_frequency       1.000000  0.366666
# Price               0.366666  1.000000
# Correlation between Price and the {colum}:                    Screen_Size_inch     Price
# Screen_Size_inch          1.000000 -0.110644
# Price                    -0.110644  1.000000
# Correlation between Price and the {colum}:                 Weight_pounds     Price
# Weight_pounds       1.000000 -0.050312
# Price              -0.050312  1.000000

# %% [markdown]
# ### Categorical features
# Generate Box plots for the different feature that hold categorical values. These features would be "Category", "GPU", "OS", "CPU_core", "RAM_GB", "Storage_GB_SSD"

# %%
sns.boxplot(data=df, x = 'Category', y='Price')
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %%
sns.boxplot(data=df, x ='GPU', y= 'Price')
# Out:
# <Axes: xlabel='GPU', ylabel='Price'>

# %%
sns.boxenplot(data =df, x = 'OS', y ='Price')
# Out:
# <Axes: xlabel='OS', ylabel='Price'>

# %%
sns.boxplot(data=df, x='CPU_core', y='Price')
# Out:
# <Axes: xlabel='CPU_core', ylabel='Price'>

# %%
sns.boxplot(data=df, x = 'RAM_GB', y='Price')
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>

# %%
sns.boxplot(data=df, x ='Storage_GB_SSD', y='Price')
# Out:
# <Axes: xlabel='Storage_GB_SSD', ylabel='Price'>
