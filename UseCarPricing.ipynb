# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="Skills Network Logo">
#     </a>
# </p>
#
#
# # Exploratory Data Analysis
#
#
# Estimated time needed: **30** minutes
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# * Explore features or characteristics to predict price of car
# * Analyze patterns and run descriptive statistical analysis
# * Group data based on identified parameters and create pivot tables
# * Identify the effect of independent attributes on price of cars

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import requests
import seaborn as sns

# %%
def download (url, fileName) :
    response = requests.get(url)
    if(response.status_code ==200):
        with open(fileName, "wb") as f:
            f.write(response.content)

# %%
file_path= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv"

# %%
download (file_path, "usedCars.csv")
file_name = "usedCars.csv"

# %%
df = pd.read_csv(file_name)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
# 3               10.0       102.0    5500.0       24          30  13950.0
# 4                8.0       115.0    5500.0       18          22  17450.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
# 3     9.791667             Medium       0    1
# 4    13.055556             Medium       0    1
#
# [5 rows x 29 columns]

# %%
df.isnull().sum()
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                     str
# aspiration               str
# num-of-doors             str
# body-style               str
# drive-wheels             str
# engine-location          str
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type              str
# num-of-cylinders         str
# engine-size            int64
# fuel-system              str
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned        str
# diesel                 int64
# gas                    int64
# dtype: object

# %%
#Peak-rpm dtype
df['peak-rpm'].dtype
# Out:
# dtype('float64')

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['int64','float64'])
#.corr() computes the correlation matrix.
#It calculates Pearson correlation coefficient between every pair of numeric columns.
numeric_df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# peak-rpm            0.279740           0.239543   -0.360305 -0.285970
# city-mpg           -0.035527          -0.225016   -0.470606 -0.665192
# highway-mpg         0.036233          -0.181877   -0.543304 -0.698142
# price              -0.082391           0.133999    0.584642  0.690628
# city-L/100km        0.066171           0.238567    0.476153  0.657373
# diesel             -0.196735          -0.101546    0.307237  0.211187
# gas                 0.196735           0.101546   -0.307237 -0.211187
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.242423 -0.550160    -0.233118    -0.110581 -0.140019
# normalized-losses  0.086802 -0.373737     0.099404     0.112360 -0.029862
# wheel-base         0.814507  0.590742     0.782097     0.572027  0.493244
# length             0.857170  0.492063     0.880665     0.685025  0.608971
# width              1.000000  0.306002     0.866201     0.729436  0.544885
# height             0.306002  1.000000     0.307581     0.074694  0.180449
# curb-weight        0.866201  0.307581     1.000000     0.849072  0.644060
# engine-size        0.729436  0.074694     0.849072     1.000000  0.572609
# bore               0.544885  0.180449     0.644060     0.572609  1.000000
# stroke             0.188829 -0.062704     0.167562     0.209523 -0.055390
# compression-ratio  0.189867  0.259737     0.156433     0.028889  0.001263
# horsepower         0.615077 -0.087027     0.757976     0.822676  0.566936
# peak-rpm          -0.245800 -0.309974    -0.279361    -0.256733 -0.267392
# city-mpg          -0.633531 -0.049800    -0.749543    -0.650546 -0.582027
# highway-mpg       -0.680635 -0.104812    -0.794889    -0.679571 -0.591309
# price              0.751265  0.135486     0.834415     0.872335  0.543155
# city-L/100km       0.673363  0.003811     0.785353     0.745059  0.554610
# diesel             0.244356  0.281578     0.221046     0.070779  0.054458
# gas               -0.244356 -0.281578    -0.221046    -0.070779 -0.054458
#
#                      stroke  compression-ratio  horsepower  peak-rpm  \
# symboling         -0.008245          -0.182196    0.075819  0.279740
# normalized-losses  0.055563          -0.114713    0.217299  0.239543
# wheel-base         0.158502           0.250313    0.371147 -0.360305
# length             0.124139           0.159733    0.579821 -0.285970
# width              0.188829           0.189867    0.615077 -0.245800
# height            -0.062704           0.259737   -0.087027 -0.309974
# curb-weight        0.167562           0.156433    0.757976 -0.279361
# engine-size        0.209523           0.028889    0.822676 -0.256733
# bore              -0.055390           0.001263    0.566936 -0.267392
# stroke             1.000000           0.187923    0.098462 -0.065713
# compression-ratio  0.187923           1.000000   -0.214514 -0.435780
# horsepower         0.098462          -0.214514    1.000000  0.107885
# peak-rpm          -0.065713          -0.435780    0.107885  1.000000
# city-mpg          -0.034696           0.331425   -0.822214 -0.115413
# highway-mpg       -0.035201           0.268465   -0.804575 -0.058598
# price              0.082310           0.071107    0.809575 -0.101616
# city-L/100km       0.037300          -0.299372    0.889488  0.115830
# diesel             0.241303           0.985231   -0.169053 -0.475812
# gas               -0.241303          -0.985231    0.169053  0.475812
#
#                    city-mpg  highway-mpg     price  city-L/100km    diesel  \
# symboling         -0.035527     0.036233 -0.082391      0.066171 -0.196735
# normalized-losses -0.225016    -0.181877  0.133999      0.238567 -0.101546
# wheel-base        -0.470606    -0.543304  0.584642      0.476153  0.307237
# length            -0.665192    -0.698142  0.690628      0.657373  0.211187
# width             -0.633531    -0.680635  0.751265      0.673363  0.244356
# height            -0.049800    -0.104812  0.135486      0.003811  0.281578
# curb-weight       -0.749543    -0.794889  0.834415      0.785353  0.221046
# engine-size       -0.650546    -0.679571  0.872335      0.745059  0.070779
# bore              -0.582027    -0.591309  0.543155      0.554610  0.054458
# stroke            -0.034696    -0.035201  0.082310      0.037300  0.241303
# compression-ratio  0.331425     0.268465  0.071107     -0.299372  0.985231
# horsepower        -0.822214    -0.804575  0.809575      0.889488 -0.169053
# peak-rpm          -0.115413    -0.058598 -0.101616      0.115830 -0.475812
# city-mpg           1.000000     0.972044 -0.686571     -0.949713  0.265676
# highway-mpg        0.972044     1.000000 -0.704692     -0.930028  0.198690
# price             -0.686571    -0.704692  1.000000      0.789898  0.110326
# city-L/100km      -0.949713    -0.930028  0.789898      1.000000 -0.241282
# diesel             0.265676     0.198690  0.110326     -0.241282  1.000000
# gas               -0.265676    -0.198690 -0.110326      0.241282 -1.000000
#
#                         gas
# symboling          0.196735
# normalized-losses  0.101546
# wheel-base        -0.307237
# length            -0.211187
# width             -0.244356
# height            -0.281578
# curb-weight       -0.221046
# engine-size       -0.070779
# bore              -0.054458
# stroke            -0.241303
# compression-ratio -0.985231
# horsepower         0.169053
# peak-rpm           0.475812
# city-mpg          -0.265676
# highway-mpg       -0.198690
# price             -0.110326
# city-L/100km       0.241282
# diesel            -1.000000
# gas                1.000000

# %% [markdown]
# <h2>Continuous Numerical Variables:</h2>
#
# <p>Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.</p>
#
# <p>In order to start understanding the (linear) relationship between an individual variable and the price, we can use "regplot" which plots the scatterplot plus the fitted regression line for the data. This will be useful later on for visualizing the fit of the simple linear regression model as well. </p>

# %% [markdown]
# <h3>Positive Linear Relationship</h4>

# %% [markdown]
# Let's find the scatterplot of "engine-size" and "price".

# %%
# Engine size as a potential variable for the price

sns.regplot(x = 'engine-size', y= 'price', data =df)
plt.ylim(0,)
# Out:
# (0.0, 53497.00499744555)

# %%
# correlation value of engine size and the price

df[['engine-size', 'price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
#Finding correlation between stroke and price
#weak correlation

print(df[['stroke', 'price']].corr())
sns.regplot(x = 'stroke', y= 'price', data= df)
plt.ylim(0,)
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000
# (0.0, 47414.1)

# %% [markdown]
# <h3>Categorical Variables</h3>
#
# <p>These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.</p>

# %% [markdown]
# Let's look at the relationship between "body-style" and "price".

# %%
sns.boxplot(data=df, x = 'body-style', y = 'price')
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %% [markdown]
# Multiple body styles are overlap with the same so that body style is not a suitable variable for predict the price.

# %% [markdown]
# lets see the relation between engine-location and price

# %%
sns.boxplot(x = 'engine-location', y ='price', data = df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %% [markdown]
# <p>Here we see that the distribution of price between these two engine-location categories, front and rear, are distinct enough to take engine-location as a potential good predictor of price.</p>

# %% [markdown]
# lets examine the dive-wheel and the price

# %%
sns.boxplot(x = 'drive-wheels' , y = 'price', data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# <p>Here we see that the distribution of price between the different drive-wheels categories differs. As such, drive-wheels could potentially be a predictor of price.</p>

# %% [markdown]
# ## Descriptive Statistical Analysis

# %% [markdown]
# <p>Let's first take a look at the variables by utilizing a description method.</p>
#
# <p>The <b>describe</b> function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.</p>
#
# This will show:
# <ul>
#     <li>the count of that variable</li>
#     <li>the mean</li>
#     <li>the standard deviation (std)</li>
#     <li>the minimum value</li>
#     <li>the IQR (Interquartile Range: 25%, 50% and 75%)</li>
#     <li>the maximum value</li>
# <ul>

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2169.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2926.000000   141.000000    3.580000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         201.000000  201.000000   201.000000  201.000000   201.000000
# mean           10.164279  103.405534  5117.665368   25.179104    30.686567
# std             4.004965   37.365700   478.113805    6.423220     6.815150
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5125.369458   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  262.000000  6600.000000   49.000000    54.000000
#
#               price  city-L/100km      diesel         gas
# count    201.000000    201.000000  201.000000  201.000000
# mean   13207.129353      9.944145    0.099502    0.900498
# std     7947.066342      2.534599    0.300083    0.300083
# min     5118.000000      4.795918    0.000000    0.000000
# 25%     7775.000000      7.833333    0.000000    1.000000
# 50%    10295.000000      9.791667    0.000000    1.000000
# 75%    16500.000000     12.368421    0.000000    1.000000
# max    45400.000000     18.076923    1.000000    1.000000

# %% [markdown]
# The default setting of "describe" skips variables of type object. We can apply the method "describe" on the variables of type 'object' as follows:

# %%
df.describe(include= ['object'])
# Out:
# C:\Users\Vish\AppData\Local\Temp\ipykernel_15864\2270142546.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include= ['object'])
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %% [markdown]
# <h3>Value Counts</h3>

# %% [markdown]
# <p>Value counts is a good way of understanding how many units of each characteristic/variable we have. We can apply the "value_counts" method on the column "drive-wheels". Don’t forget the method "value_counts" <b>only works on pandas series, not pandas dataframes. As a result, we only include one bracket <code>df['drive-wheels']</code>, not two brackets <code>df[['drive-wheels']]</code> </b>.</p>

# %%
df['drive-wheels'].value_counts()
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %% [markdown]
# We can convert the series to a dataframe as follows:

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
drive_wheel_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheel_counts.reset_index(inplace=True)
drive_wheel_counts = drive_wheel_counts.rename(columns={'drive-wheels': 'value_counts'})
drive_wheel_counts
# Out:
#   value_counts  count
# 0          fwd    118
# 1          rwd     75
# 2          4wd      8

# %%
drive_wheel_counts.index.name = 'drive-wheel'
drive_wheel_counts
# Out:
#             value_counts  count
# drive-wheel
# 0                    fwd    118
# 1                    rwd     75
# 2                    4wd      8

# %% [markdown]
# We can repeat the above process for the variable 'engine-location'.

# %%
engine_location_counts = df['engine-location'].value_counts().to_frame()
engine_location_counts.reset_index(inplace=True)
engine_location_counts.index.name = 'index'
engine_location_counts
# Out:
#       engine-location  count
# index
# 0               front    198
# 1                rear      3

# %% [markdown]
# <p>After examining the value counts of the engine location, we see that engine location would not be a good predictor variable for the price. This is because we only have three cars with a rear engine and 198 with an engine in the front, so this result is skewed. Thus, we are not able to draw any conclusions about the engine location.</p>

# %% [markdown]
# ## Basics of Grouping

# %% [markdown]
# <p>The "groupby" method groups data by different categories. The data is grouped based on one or several variables, and analysis is performed on the individual groups.</p>
#
# <p>For example, let's group by the variable "drive-wheels". We see that there are 3 different categories of drive wheels.</p>

# %%
df['drive-wheels'].unique()
# Out:
# <StringArray>
# ['rwd', 'fwd', '4wd']
# Length: 3, dtype: str

# %%
df_group_one = df[['drive-wheels','body-style','price']]
df_group_one
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
# agg() means aggregate (apply a function to each group).
df_group = df_group_one.groupby(df['drive-wheels'], as_index=False).agg({'price': 'mean'})
df_group
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# <p>From our data, it seems rear-wheel drive vehicles are, on average, the most expensive, while 4-wheel and front-wheel are approximately the same in price.</p>
#
# <p>You can also group by multiple variables. For example, let's group by both 'drive-wheels' and 'body-style'. This groups the dataframe by the unique combination of 'drive-wheels' and 'body-style'. We can store the results in the variable 'grouped_test1'.</p>

# %%
df_group_two = df[['drive-wheels', 'body-style', 'price']]
df_grpest = df_group_two.groupby(['drive-wheels', 'body-style'], as_index=False).mean()
df_grpest
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# <p>This grouped data is much easier to visualize when it is made into a pivot table. A pivot table is like an Excel spreadsheet, with one variable along the column and another along the row. We can convert the dataframe to a pivot table using the method "pivot" to create a pivot table from the groups.</p>
#
# <p>In this case, we will leave the drive-wheels variable as the rows of the table, and pivot body-style to become the columns of the table:</p>

# %%
group_pivot = df_grpest.pivot(index = 'drive-wheels', columns='body-style')
group_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
# missing value handled
group_pivot = group_pivot.fillna(0)
group_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# ## Model Trainig
#
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
df[['horsepower','curb-weight','engine-size','highway-mpg']].head()
# Out:
#    horsepower  curb-weight  engine-size  highway-mpg
# 0       111.0         2548          130           27
# 1       111.0         2548          130           27
# 2       154.0         2823          152           26
# 3       102.0         2337          109           30
# 4       115.0         2824          136           22

# %%
# define predictor and target variables
x = df[['highway-mpg']]
y = df['price']

# create a linear regression object
lm = LinearRegression ()
# then train the model using lm.fit() find the parameters b0 and b1 (intercept and the slope)
lm.fit(x,y)

# we can obtain the prediction
yhat = lm.predict(x)
print("Intercet: ",lm.intercept_)
print("Slope: ", lm.coef_)
# Out:
# Intercet:  38423.3058581574
# Slope:  [-821.73337832]

# %% [markdown]
#  price = [-821.73337832] * highway-mpg + 38423.3058581574

# %%
# Multiple linear regression
x = df[['horsepower','curb-weight','engine-size','highway-mpg']] # predictor variables 
y = df['price'] # target vaiable

# Linear regression model object create
multiple_lm = LinearRegression ()

# model training
multiple_lm.fit(x,y)

yhat = multiple_lm.predict(x)
print("Intercep: ",multiple_lm.intercept_)
print("Coefficients: ",multiple_lm.coef_)
# Out:
# Intercep:  -15806.62462632923
# Coefficients:  [53.49574423  4.70770099 81.53026382 36.05748882]

# %%
# predict new price usig the trained model

new_data = [[200, 2800, 100 ,31]]

# predict the new data from model
predicted_price = multiple_lm.predict(new_data)
print("Predicted Price = ", predicted_price)
# Out:
# Predicted Price =  [17344.89553923]
# C:\Users\Vish\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# residual plot - error graph repersent

sns.regplot(x  = 'engine-size', y= 'price', data  =df)
plt.ylim(0,)
# Out:
# (0.0, 53373.48073431374)

# %%
sns.residplot(x='engine-size', y ='price', data=df)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
sns.residplot(x = 'stroke', y='price', data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
ax1 = sns.kdeplot(data = df['price'],color='r', label = 'Actual Value', legend=True)
sns.kdeplot(data = yhat, color ='blue', label = 'predicted value', legend= True, ax=ax1)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
#we use pcolor for plot the pivot table
plt.pcolor(group_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %% [markdown]
# <p>The heatmap plots the target variable (price) proportional to colour with respect to the variables 'drive-wheel' and 'body-style' on the vertical and horizontal axis, respectively. This allows us to visualize how the price is related to 'drive-wheel' and 'body-style'.</p>
#
# <p>The default labels convey no useful information to us. Let's change that:</p>

# %%
fig , ax = plt.subplots()
im = ax.pcolor(group_pivot, cmap="RdBu")

#Label name
row_labels = group_pivot.columns.levels[1]
col_labels = group_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(group_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(group_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %% [markdown]
# # Linear regression

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='str')

# %%
from sklearn.linear_model import LinearRegression
x =df[['curb-weight', 'horsepower']]
y = df['price']

lm = LinearRegression()

lm.fit(x,y)
lm.coef_, lm.intercept_
# Out:
# (array([ 7.97165442, 88.53228139]), np.float64(-16320.489962555403))

# %% [markdown]
# # Polynomial Linear Regression

# %%
#features are not linera with the predicted feature. the polynomial of features are linear with the predicted features.

""" from sklearn.preprocessing import PolynomialFeatures

py = PolynomialFeatures(degree=2,include_bias=False)
x_polly = py.fit_transform(df[['horsepower','curb-weight']]) """
# Out:
# " from sklearn.preprocessing import PolynomialFeatures\n\npy = PolynomialFeatures(degree=2,include_bias=False)\nx_polly = py.fit_transform(df[['horsepower','curb-weight']]) "

# %%
from sklearn.preprocessing import StandardScaler

""" Scale = StandardScaler()

Scale.fit(df[['horsepower','curb-weight']])
x_scale = Scale.transform(df[['horsepower','curb-weight']]) """
# Out:
# " Scale = StandardScaler()\n\nScale.fit(df[['horsepower','curb-weight']])\nx_scale = Scale.transform(df[['horsepower','curb-weight']]) "

# %%
## full code for polynomial feature with linear regression

from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

y = df['price']

pr = PolynomialFeatures(degree=2, include_bias=False)
x_polly  = pr.fit_transform(df[['horsepower','curb-weight','engine-size','highway-mpg']])

Scale = StandardScaler()
x_scale = Scale.fit_transform(x_polly)

lm = LinearRegression()
lm.fit(x_scale, y)

lm.intercept_ , lm.coef_
# Out:
# (np.float64(13207.129353233831),
#  array([ 1.41632561e+04,  4.91798038e+03, -4.40398243e+03,  1.23841638e+03,
#          1.60800303e+04, -2.85736822e+04, -1.39638682e+04, -1.21044140e+03,
#          2.15240148e+03,  2.14711026e+04, -1.86499209e+03,  1.27611345e+03,
#          2.77573770e+01,  2.08664057e+03]))

# %% [markdown]
# ## automate pipeline linear regression

# %%
from sklearn.pipeline import Pipeline

input  = [('polynomial', PolynomialFeatures(degree=2, include_bias=False)), ('scale', StandardScaler()), ('model', LinearRegression())]

pipe = Pipeline(input)
pipe.fit(df[['horsepower','curb-weight','engine-size','highway-mpg']], df['price'])

print(pipe.named_steps['model'].coef_) 
print(pipe.named_steps['model'].intercept_)
# Out:
# [ 1.41632561e+04  4.91798038e+03 -4.40398243e+03  1.23841638e+03
#   1.60800303e+04 -2.85736822e+04 -1.39638682e+04 -1.21044140e+03
#   2.15240148e+03  2.14711026e+04 -1.86499209e+03  1.27611345e+03
#   2.77573770e+01  2.08664057e+03]
# 13207.129353233831

# %% [markdown]
# # KDE plot (Kernal Density Estimatation) for Model Evalution

# %% [markdown]
# This uses probability density function to plot the data distribution of the dataset

# %%
from sklearn.model_selection import train_test_split


x = df[['horsepower','curb-weight','engine-size','highway-mpg']]
y = df ['price']

# Data split
X_train, X_test, Y_train,Y_test = train_test_split(x , y, test_size= 0.2, random_state=42)

# Polynomial transform
poly = PolynomialFeatures(degree=2, include_bias=False)
x_polly = poly.fit_transform(X_train)

x_test_polly = poly.transform(X_test)
#testing data should scaleup not fit() only transform.
# we scale up testing data using the mean and std of training data


# Data Normalization
SCALE = StandardScaler()
x_scale = SCALE.fit_transform(x_polly)
x_test_scale = SCALE.transform(x_test_polly)

# Model Train
li_model = LinearRegression()

li_model.fit(x_scale,Y_train)
Y_predict = li_model.predict(x_test_scale)

# %%
import seaborn as sns
# plotting KDE 
plt.figure(figsize=(8,5))

sns.kdeplot(Y_test, label="Actual", fill=True, color='green')
sns.kdeplot(Y_predict, label="Predict", fill=True, color='red')

plt.xlabel("Target Variable")
plt.ylabel("Density")
plt.title('KDE Plot of Actual vs. Predicted Values')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluation model using MSE (Mean Squard Error) and R^2 (R Squard)
# # R Squared - R-squared (Coefficient of Determination) measures:
#
# ## 🔹 How much of the variance in the target variable is explained by the model.

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(Y_test, Y_predict)
print("Mean Squard Error = ", mse)

print("R squared error: ")
li_model.score(x_test_scale, Y_predict)
# Out:
# Mean Squard Error =  29838190.68987762
# R squared error:
# 1.0

# %%
li_model.fit(df[['highway-mpg']], df['price'])

new_input = np.arange(1,101,1).reshape(-1,1)
li_model.predict(new_input)
# Out:
# C:\Users\Vish\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([ 37601.57247984,  36779.83910151,  35958.10572319,  35136.37234487,
#         34314.63896655,  33492.90558823,  32671.1722099 ,  31849.43883158,
#         31027.70545326,  30205.97207494,  29384.23869662,  28562.50531829,
#         27740.77193997,  26919.03856165,  26097.30518333,  25275.57180501,
#         24453.83842668,  23632.10504836,  22810.37167004,  21988.63829172,
#         21166.9049134 ,  20345.17153508,  19523.43815675,  18701.70477843,
#         17879.97140011,  17058.23802179,  16236.50464347,  15414.77126514,
#         14593.03788682,  13771.3045085 ,  12949.57113018,  12127.83775186,
#         11306.10437353,  10484.37099521,   9662.63761689,   8840.90423857,
#          8019.17086025,   7197.43748192,   6375.7041036 ,   5553.97072528,
#          4732.23734696,   3910.50396864,   3088.77059031,   2267.03721199,
#          1445.30383367,    623.57045535,   -198.16292297,  -1019.8963013 ,
#         -1841.62967962,  -2663.36305794,  -3485.09643626,  -4306.82981458,
#         -5128.5631929 ,  -5950.29657123,  -6772.02994955,  -7593.76332787,
#         -8415.49670619,  -9237.23008451, -10058.96346284, -10880.69684116,
#        -11702.43021948, -12524.1635978 , -13345.89697612, -14167.63035445,
#        -14989.36373277, -15811.09711109, -16632.83048941, -17454.56386773,
#        -18276.29724606, -19098.03062438, -19919.7640027 , -20741.49738102,
#        -21563.23075934, -22384.96413767, -23206.69751599, -24028.43089431,
#        -24850.16427263, -25671.89765095, -26493.63102927, -27315.3644076 ,
#        -28137.09778592, -28958.83116424, -29780.56454256, -30602.29792088,
#        -31424.03129921, -32245.76467753, -33067.49805585, -33889.23143417,
#        -34710.96481249, -35532.69819082, -36354.43156914, -37176.16494746,
#        -37997.89832578, -38819.6317041 , -39641.36508243, -40463.09846075,
#        -41284.83183907, -42106.56521739, -42928.29859571, -43750.03197404])

# %% [markdown]
# # Cross validation

# %% [markdown]
# To prevent the generalize error scinario, we are using cross validation. so it means we partition the data set in to training and testing and each testing fold is act like a training fold at a different training phrase. So that we take a best result for the model.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

# cross value predict will determine the predicted values for the test data by the model in each phase
predicted_val = cross_val_predict(lm, x, y, cv=3)
predicted_price

# cross value score will determine the R squared of of testing fold in each pharse.
scores = cross_val_score(lm,x ,y, cv=3) 
print(scores)
predicted_price
# Out:
# [0.78742931 0.73702144 0.55859373]
# array([17344.89553923])

# %% [markdown]
# ## Ridge Regression Model

# %% [markdown]
# To prevent the model overfitting, we use ridge regression. it has a parameter called 'alpha'. so when increase the alpha the coefficients of higher order polynomials will decrease.

# %% [markdown]
# So to get a best value for alpha we predict the the R squared value for different alpha of the Ridge Model, and choose the alpha value that gives the higher R squared.

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

x = df[['horsepower','curb-weight','engine-size']]
y = df['price']

x_train, x_test, y_train, y_test = train_test_split(x , y , test_size=0.25, random_state=42)


RidgeModel = Ridge(alpha=0.1)
RidgeModel.fit(x_train, y_train)
yhat = RidgeModel.predict(x_test)

print("R squared using model.score= ", RidgeModel.score(x_test, y_test))
print("R squared from r2_score = ", r2_score(y_test, yhat))

"""
Predict using x_test

Compare with y_test

Return R²
"""
# Out:
# R squared using model.score=  0.7791074515140302
# R squared from r2_score =  0.7791074515140302
# '\nPredict using x_test\n\nCompare with y_test\n\nReturn R²\n'

# %% [markdown]
# # Grid Search

# %% [markdown]
# Allows us to analyze the model through multiple free parmeters and get a optimum values for that parameters.

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

parameters = [{'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]}]

RidgeModel = Ridge()
GridSeacrch = GridSearchCV(RidgeModel, parameters, cv=4)

GridSeacrch.fit(df[['horsepower','curb-weight','engine-size']], df['price'])

print("Best Estimator value for aplha = ", GridSeacrch.best_estimator_)
## we can also get the mean score value
scores = GridSeacrch.cv_results_
scores['mean_test_score']
# Out:
# Best Estimator value for aplha =  Ridge(alpha=10000)
# array([0.67179831, 0.67179831, 0.67179834, 0.67179855, 0.67180068,
#        0.67182183, 0.67201981, 0.67293786])
