# %% [markdown]
# <h1> Laptop Pricing Dataset Cleaning with Data Analysis Techniques </h1>

# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
#  - Handle missing data in different ways
#  - Correct the data type of different data values as per requirement
#  - Standardize and normalize the appropriate data attributes
#  - Visualize the data as grouped bar graph using Binning
#  - Cnverting a categorical data into numerical indicator variables

# %%
## import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
#download the dataset

def download(url, fileName):
    response = requests.get(url)
    if(response.status_code == 200):
        with open(fileName, "wb") as f:
            f.write(response.content)

# %%
file_path= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod1.csv"

# %%
download(file_path, "laptops.csv")
file_name = "laptops.csv"

# %%
# we are going to create a datafram as df using the laptops.csv

df = pd.read_csv(file_name)
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# 2          39.624            2.7       8             256       2.20    946
# 3          33.782            1.6       8             128       1.22   1244
# 4          39.624            1.8       8             256       1.91    837

# %%
#we get the summary about dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      238 non-null    int64
#  1   Manufacturer    238 non-null    str
#  2   Category        238 non-null    int64
#  3   Screen          238 non-null    str
#  4   GPU             238 non-null    int64
#  5   OS              238 non-null    int64
#  6   CPU_core        238 non-null    int64
#  7   Screen_Size_cm  234 non-null    float64
#  8   CPU_frequency   238 non-null    float64
#  9   RAM_GB          238 non-null    int64
#  10  Storage_GB_SSD  238 non-null    int64
#  11  Weight_kg       233 non-null    float64
#  12  Price           238 non-null    int64
# dtypes: float64(3), int64(8), str(2)
# memory usage: 24.3 KB

# %%
## rounded the column screensize cm to nearest two decimal places.
## consider as a dataframe

df[['Screen_Size_cm']] = df[['Screen_Size_cm']].astype("float")
df[['Screen_Size_cm']] = np.round(df[['Screen_Size_cm']], 2)
df['Screen_Size_cm'].head()
# Out:
# 0    35.56
# 1    39.62
# 2    39.62
# 3    33.78
# 4    39.62
# Name: Screen_Size_cm, dtype: float64

# %% [markdown]
# # Task 1: Finding Missing Values

# %% [markdown]
# <p> Evaluate the data set for missing data </p>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Manufacturer      0
# Category          0
# Screen            0
# GPU               0
# OS                0
# CPU_core          0
# Screen_Size_cm    4
# CPU_frequency     0
# RAM_GB            0
# Storage_GB_SSD    0
# Weight_kg         5
# Price             0
# dtype: int64

# %%
## Alnternate way
missing_data = df.isnull()
print(missing_data.head())

for colum in missing_data.columns.values.tolist():
    print(missing_data[colum].value_counts())
    print("")
# Out:
#    Unnamed: 0  Manufacturer  Category  Screen    GPU     OS  CPU_core  \
# 0       False         False     False   False  False  False     False
# 1       False         False     False   False  False  False     False
# 2       False         False     False   False  False  False     False
# 3       False         False     False   False  False  False     False
# 4       False         False     False   False  False  False     False
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           False          False   False           False      False  False
# 1           False          False   False           False      False  False
# 2           False          False   False           False      False  False
# 3           False          False   False           False      False  False
# 4           False          False   False           False      False  False
# Unnamed: 0
# False    238
# Name: count, dtype: int64
#
# Manufacturer
# False    238
# ...

# %% [markdown]
# ## Task 2: Replace with Mean
#  <p> weight can be replace with the mean of the column data </p>

# %%
df['Weight_kg'].dtype
# Out:
# dtype('float64')

# %%
mean_weights = np.round(df['Weight_kg'].mean(axis=0), 2)
print("Mean of weight_kg column: " , mean_weights)
# Out:
# Mean of weight_kg column:  1.86

# %%
df['Weight_kg'] = df['Weight_kg'].fillna(mean_weights)
print(df['Weight_kg'].head())

df['Weight_kg'].isnull().sum()
# Out:
# 0    1.60
# 1    2.20
# 2    2.20
# 3    1.22
# 4    1.91
# Name: Weight_kg, dtype: float64
# np.int64(0)

# %% [markdown]
# ### Replace with the most frequent value
# Missing values in attributes that have categorical data are best replaced using the most frequent value. We note that values in "Screen_Size_cm" attribute are categorical in nature, and some values are missing. Therefore, write a code to replace the missing values of Screen Size with the most frequent value of the attribute.

# %%
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           35.56            1.6       8             256       1.60    978
# 1           39.62            2.0       4             256       2.20    634
# 2           39.62            2.7       8             256       2.20    946
# 3           33.78            1.6       8             128       1.22   1244
# 4           39.62            1.8       8             256       1.91    837

# %%
df['Screen'].value_counts()
# Out:
# Screen
# Full HD      161
# IPS Panel     77
# Name: count, dtype: int64

# %%
#maxium value use for screen 
commonvalue =df['Screen'].value_counts().idxmax()

# %%
#replace null values of screen with Full HD
common_screen_size = df['Screen_Size_cm'].value_counts().idxmax()
df["Screen_Size_cm"] = df["Screen_Size_cm"].fillna(common_screen_size)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Manufacturer      0
# Category          0
# Screen            0
# GPU               0
# OS                0
# CPU_core          0
# Screen_Size_cm    0
# CPU_frequency     0
# RAM_GB            0
# Storage_GB_SSD    0
# Weight_kg         0
# Price             0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# Manufacturer          str
# Category            int64
# Screen                str
# GPU                 int64
# OS                  int64
# CPU_core            int64
# Screen_Size_cm    float64
# CPU_frequency     float64
# RAM_GB              int64
# Storage_GB_SSD      int64
# Weight_kg         float64
# Price               int64
# dtype: object

# %% [markdown]
# # Task - 3
#
# ### Fixing the data types
# Both "Weight_kg" and "Screen_Size_cm" are seen to have the data type "Object", while both of them should be having a data type of "float". Write a code to fix the data type of these two columns.

# %%
df[["Weight_kg", "Screen_Size_cm"]] = df[["Weight_kg", "Screen_Size_cm"]].astype("float")
df[["Weight_kg", "Screen_Size_cm"]].dtypes
# Out:
# Weight_kg         float64
# Screen_Size_cm    float64
# dtype: object

# %% [markdown]
# # Task - 4
#
# ### Data Standardization
# The value of Screen_size usually has a standard unit of inches. Similarly, weight of the laptop is needed to be in pounds. Use the below mentioned units of conversion and write a code to modify the columns of the dataframe accordingly. Update their names as well.
#
# ```{math}
# 1 inch = 2.54 cm
# 1 kg   = 2.205 pounds
# ```

# %%
#screen size covert to inches
df["Screen_Size_cm"] = df ["Screen_Size_cm"]/2.54

#Weight convert to pounds
df["Weight_kg"] = df["Weight_kg"]*2.205

# %%
#rename the coulmn names
df.rename(columns={"Screen_Size_cm" : "Screen_Size_Inch", "Weight_kg": "Weight_pounds" }, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_Inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0         14.000000            1.6       8             256        3.52800
# 1         15.598425            2.0       4             256        4.85100
# 2         15.598425            2.7       8             256        4.85100
# 3         13.299213            1.6       8             128        2.69010
# 4         15.598425            1.8       8             256        4.21155
#
#    Price
# 0    978
# 1    634
# 2    946
# 3   1244
# 4    837

# %%
df['Screen_Size_Inch'] = np.round(df['Screen_Size_Inch'],2)
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_Inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0            1.6       8             256        3.52800
# 1              15.6            2.0       4             256        4.85100
# 2              15.6            2.7       8             256        4.85100
# 3              13.3            1.6       8             128        2.69010
# 4              15.6            1.8       8             256        4.21155
#
#    Price
# 0    978
# 1    634
# 2    946
# 3   1244
# 4    837

# %% [markdown]
# ### Data Normalization
# Often it is required to normalize a continuous data attribute. Write a code to normalize the "CPU_frequency" attribute with respect to the maximum value available in the dataset.

# %%
df['CPU_frequency'] = df['CPU_frequency']/df['CPU_frequency'].max()
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_Inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256        3.52800
# 1              15.6       0.689655       4             256        4.85100
# 2              15.6       0.931034       8             256        4.85100
# 3              13.3       0.551724       8             128        2.69010
# 4              15.6       0.620690       8             256        4.21155
#
#    Price
# 0    978
# 1    634
# 2    946
# 3   1244
# 4    837

# %% [markdown]
# # Task - 5
#
# ### Binning
# Binning is a process of creating a categorical attribute which splits the values of a continuous data into a specified number of groups. In this case, write a code to create 3 bins for the attribute "Price". These bins would be named "Low", "Medium" and "High". The new attribute will be named "Price-binned".

# %%
price_group = ["Low", "Medium", "High"]
price_binned = np.linspace(min(df['Price']), max(df['Price']), 4)
price_binned
# Out:
# array([ 527.        , 1621.33333333, 2715.66666667, 3810.        ])

# %%
df['Price_binned'] = pd.cut(df["Price"],price_binned, labels=price_group, include_lowest=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_Inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256        3.52800
# 1              15.6       0.689655       4             256        4.85100
# 2              15.6       0.931034       8             256        4.85100
# 3              13.3       0.551724       8             128        2.69010
# 4              15.6       0.620690       8             256        4.21155
#
#    Price Price_binned
# 0    978          Low
# 1    634          Low
# 2    946          Low
# 3   1244          Low
# ...

# %%
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(df['Price_binned'], bins=3)
plt.pyplot.xlabel("Price Range")
plt.pyplot.ylabel("Count")
plt.pyplot.title("Price Bin Graph")
# Out:
# Text(0.5, 1.0, 'Price Bin Graph')

# %% [markdown]
# # Task - 6
#
# ### Indicator variables
# Convert the "Screen" attribute of the dataset into 2 indicator variables, "Screen-IPS_panel" and "Screen-Full_HD". Then drop the "Screen" attribute from the dataset.

# %%
df_dummies = pd.get_dummies(df['Screen'])
df_dummies
# Out:
#      Full HD  IPS Panel
# 0      False       True
# 1       True      False
# 2       True      False
# 3      False       True
# 4       True      False
# ..       ...        ...
# 233    False       True
# 234     True      False
# 235    False       True
# 236     True      False
# 237     True      False
#
# [238 rows x 2 columns]

# %%
#rename dummy variables
df_dummies.rename(columns={"Full HD": "Screen-Full_HD", "IPS Panel": "Screen-IPS_panel"},inplace=True)

# %%
#combine df with df_dummies
df = pd.concat([df,df_dummies], axis=1)
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_Inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256        3.52800
# 1              15.6       0.689655       4             256        4.85100
# 2              15.6       0.931034       8             256        4.85100
# 3              13.3       0.551724       8             128        2.69010
# 4              15.6       0.620690       8             256        4.21155
#
#    Price Price_binned  Screen-Full_HD  Screen-IPS_panel
# 0    978          Low           False              True
# ...

# %%
#drop the screen column
df.drop("Screen", axis = 1, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_Inch  \
# 0           0         Acer         4    2   1         5              14.0
# 1           1         Dell         3    1   1         3              15.6
# 2           2         Dell         3    1   1         7              15.6
# 3           3         Dell         4    2   1         5              13.3
# 4           4           HP         4    2   1         7              15.6
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  Price Price_binned  \
# 0       0.551724       8             256        3.52800    978          Low
# 1       0.689655       4             256        4.85100    634          Low
# 2       0.931034       8             256        4.85100    946          Low
# 3       0.551724       8             128        2.69010   1244          Low
# 4       0.620690       8             256        4.21155    837          Low
#
#    Screen-Full_HD  Screen-IPS_panel
# ...

# %% [markdown]
# ## Descriptive Data Analysis

# %%
# plot (x,y)
import matplotlib as plt
from matplotlib import pyplot

x = df['Manufacturer']
y = df['Price']

plt.pyplot.plot(x,y)

# %%
plt.pyplot.scatter(x,y)

# %%
plt.pyplot.hist(df['Price'], bins=4, edgecolor = 'Black')
# Out:
# (array([121.,  92.,  19.,   6.]),
#  array([ 527.  , 1347.75, 2168.5 , 2989.25, 3810.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.pyplot.bar(df['Manufacturer'], df['Price'])
# Out:
# <BarContainer object of 238 artists>

# %%
plt.pyplot.scatter(df['Screen_Size_Inch'], df['Price'])

# %%
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_Inch  \
# 0           0         Acer         4    2   1         5              14.0
# 1           1         Dell         3    1   1         3              15.6
# 2           2         Dell         3    1   1         7              15.6
# 3           3         Dell         4    2   1         5              13.3
# 4           4           HP         4    2   1         7              15.6
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  Price Price_binned  \
# 0       0.551724       8             256        3.52800    978          Low
# 1       0.689655       4             256        4.85100    634          Low
# 2       0.931034       8             256        4.85100    946          Low
# 3       0.551724       8             128        2.69010   1244          Low
# 4       0.620690       8             256        4.21155    837          Low
#
#    Screen-Full_HD  Screen-IPS_panel
# ...

# %%
df_test = df[['Manufacturer', 'Screen_Size_Inch', 'Price']]
df_group = df_test.groupby(['Manufacturer', 'Screen_Size_Inch'], as_index=False).mean()
df_group
# Out:
#    Manufacturer  Screen_Size_Inch        Price
# 0          Acer              13.0  1256.000000
# 1          Acer              14.0  1001.333333
# 2          Acer              15.0  1054.250000
# 3          Acer              15.6  1159.000000
# 4          Acer              17.0  1000.000000
# 5          Asus              14.0  1353.000000
# 6          Asus              15.0  1000.000000
# 7          Asus              15.6  1067.444444
# 8          Asus              17.3  3810.000000
# 9          Dell              12.5  2254.000000
# 10         Dell              13.0  1640.250000
# 11         Dell              13.3  1620.250000
# 12         Dell              14.0  1519.076923
# 13         Dell              15.0  2204.333333
# 14         Dell              15.6  1302.350000
# 15         Dell              17.3  3665.000000
# 16           HP              12.5  1908.000000
# 17           HP              13.0  1252.000000
# 18           HP              13.3  1066.000000
# ...

# %%
# to display clearly we use pivot table. one variable as index another as column
df_pivot = df_group.pivot(index="Manufacturer" ,columns="Screen_Size_Inch")
df_pivot
# Out:
#                     Price                                             \
# Screen_Size_Inch     12.0    12.5     13.0         13.3         14.0
# Manufacturer
# Acer                  NaN     NaN  1256.00          NaN  1001.333333
# Asus                  NaN     NaN      NaN          NaN  1353.000000
# Dell                  NaN  2254.0  1640.25  1620.250000  1519.076923
# HP                    NaN  1908.0  1252.00  1066.000000  1463.636364
# Huawei                NaN     NaN  1714.00          NaN          NaN
# Lenovo            2039.75     NaN  1134.80  1162.500000  1645.000000
# MSI                   NaN     NaN      NaN          NaN          NaN
# Razer                 NaN     NaN      NaN          NaN  3301.000000
# Samsung               NaN     NaN      NaN  1999.500000          NaN
# Toshiba               NaN     NaN  1680.00  1763.833333  1617.666667
# Xiaomi                NaN     NaN  1188.00          NaN          NaN
#
#
# ...

# %%
# we use heatmap to plot target variable against multiple variables

plt.pyplot.pcolor(df_pivot, cmap="RdBu")
plt.pyplot.colorbar()
plt.pyplot.show()
